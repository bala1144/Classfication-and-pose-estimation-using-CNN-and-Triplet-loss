# %%
import os
import numpy as np
import util as util
import cv2
import random

# Steps for data generation

# load the image from the path
# function to read corresponding pose from the file (pose are stored in quaterions)
# create a class or struct for the samples

# s_train =  real + fine
# s_db = coarse folder
# s_test = real

# batch generator function -> triplet generation
# anchor = randomly chosen from the training set
# Puller = most similar to anchor from the db
# pusher = same object different pose and different object pusher


def get_puller(anchor,anc_class,s_db):
    #print('building puller')
    thresh = 75
    thetha_list = []
    puller = -1

    #select only sample from the class
    indx = [i for i in range(s_db['pose'].shape[0]) if s_db['label'][i] ==  anc_class]
    other_indx = [i for i in range(s_db['pose'].shape[0]) if s_db['label'][i] !=  anc_class]
    
    #choosing the puller
    #same class pusher  - code enforces hard constraint on the network
    for idx in indx:
        test_pusher = s_db['pose'][idx, :]
        anchor = list(map(float, anchor))
        test_pusher = list(map(float, test_pusher))

        x = np.absolute(np.dot(test_pusher, anchor) )
        theth_var = np.rad2deg(2 * np.arccos(x))
        thetha_list.append(theth_var)

    puller = np.argmin(thetha_list) 
    
    #same class pusher with the threshold
    #sort the generated thetha list and the choose the nth smallest element as the same class pusher
    a = thetha_list
    s_pusher_value = np.partition(a, thresh)[thresh]
    s_pusher = list(thetha_list).index(s_pusher_value)
   
    #the other class pusher
    #randomly pick another pusher from different class
    other_class_pusher = np.random.choice(other_indx)
    return puller + indx[0], s_pusher + indx[0], other_class_pusher


def gen_triplet_list(s_train,s_db):
    print('building triplet list')
    triplet_list = []


    #precompute the triplet list, to improve the training 
    for i in range(s_train['pose'].shape[0]):
        test_anchor = s_train['pose'][i, :]
        test_anchor_class = s_train['label'][i]

        puller, s_pusher,other_class_pusher = get_puller(test_anchor, test_anchor_class, s_db)
        triplet_list.append([i,puller,s_pusher])
        triplet_list.append([i,puller,other_class_pusher])

    print('number of triplets = ', len(triplet_list))
    return triplet_list

def get_batch(s_train,s_db,triplet_list,batch_size):

    #define the batch containers
    batch_img = []
    batch_class = []
    batch_pose = []
    
    #randomly sample the index from the range of the triplet list and iterate over them
    idx = random.sample(range(0, len(triplet_list)),batch_size)
    for i in idx:
        t = triplet_list[i]
        
        #appending images
        batch_img.append(s_train['img'][t[0],:,:,:])
        batch_img.append(s_db['img'][t[1],:,:,:])
        batch_img.append(s_db['img'][t[2],:,:,:])
        
        #appending pose
        batch_pose.append(s_train['pose'][t[0],:])
        batch_pose.append(s_db['pose'][t[1],:])
        batch_pose.append(s_db['pose'][t[2],:])
        
        #appending class
        batch_class.append(s_train['label'][t[0]])
        batch_class.append(s_db['label'][t[1]])
        batch_class.append(s_db['label'][t[2]])

    #yield(np.asarray(batch))
    return np.asarray(batch_img),np.asarray(batch_class),np.asarray(batch_pose)

if '__main__' == __name__:

    base_path = os.getcwd()
    print('path = ', base_path)

    fine_set = util.loadDataset(os.path.join(base_path, "dataset/fine"), 'poses.txt')
    s_db = util.loadDataset(os.path.join(base_path, "dataset/coarse"), 'poses.txt')

    S_db_img=s_db['img']
    S_db_class=s_db['label']
    S_db_quat=s_db['pose']
    
    
    
    real_set = util.loadDataset(os.path.join(base_path, "dataset/real"), 'poses.txt')
    train_idx, test_idx = util.read_indicies(os.path.join(base_path, "dataset/real"), 'training_split.txt')
    s_train = util.build_train_set(real_set,fine_set,train_idx)
    S_train_img=s_train['img']
    S_train_class=s_train['label']
    S_train_quat=s_train['pose']
    

    s_test = util.build_test_set(real_set,test_idx) 
    S_test_img=s_test['img']
    S_test_class=s_test['label']
    S_test_quat=s_test['pose']
    
    
    triplet_list = gen_triplet_list(s_train,s_db)

    print("Db , train, test shapes \n")
    print(S_db_img.shape)
    print(S_train_img.shape)
    print(S_test_img.shape)
    
    print("Db , train, test class annotations \n")
    print(S_train_class)
# Out:
# path =  C:\Users\bala\Documents\myprojects\3d Object Instance segmentation and Pose Estimation\new_source\Classfication-and-pose-estimation-using-CNN-and-Triplet-loss
# ['ape', 'benchvise', 'cam', 'cat', 'duck']
# (5055, 64, 64, 3) (5055, 4) (5055,)
# ['ape', 'benchvise', 'cam', 'cat', 'duck']
# (1334, 64, 64, 3) (1334, 4) (1334,)
# ['ape', 'benchvise', 'cam', 'cat', 'duck']
# (5890, 64, 64, 3) (5890, 4) (5890,)
# building train set
# (7410, 64, 64, 3) (7410, 4) (7410,)
# building test set
# (3535, 64, 64, 3) (3535, 4) (3535,)
# building triplet list
# C:\Users\bala\Anaconda3\envs\ex3\lib\site-packages\ipykernel_launcher.py:41: RuntimeWarning: invalid value encountered in arccos
# number of triplets =  14820
# Db , train, test shapes
#
# (1334, 64, 64, 3)
# (7410, 64, 64, 3)
# (3535, 64, 64, 3)
# Db , train, test class annotations
#
# [0 0 0 ..., 4 4 4]

# %%
S_db_quat[1]
# Out:
# array([-0.19322862, -0.6801931 ,  0.6801931 , -0.19322862], dtype=float32)

# %%
import tensorflow as tf
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

from util import *

# %load_ext autoreload
# %autoreload 2

# %%
##Normalising the values between (0,1)
S_db_img = np.array(S_db_img, dtype="float32", copy = True)
S_train_img = np.array(S_train_img, dtype="float32", copy = True)
S_test_img = np.array(S_test_img, dtype="float32", copy = True)

for i in range(0, len(S_db_img)):
    S_db_img[i] = normalize_img(S_db_img[i])

for i in range(0, len(S_train_img)):
    S_train_img[i] = normalize_img(S_train_img[i])

for i in range(0, len(S_test_img)):
    S_test_img[i] = normalize_img(S_test_img[i])

# %%
# Displaying a batch of anchor, puller, and pusher
batch_size = 3
batch_array,batch_class, batch_quat = get_batch(s_train, s_db, triplet_list, batch_size)

print(batch_array.shape)
util.plot_images(batch_array)
# Out:
# (9, 64, 64, 3)

# %%
x = tf.placeholder(tf.float32, shape=[None, 64, 64, 3], name='x')

#LAYERS
layer_conv1 = new_conv_layer(input=x, num_input_channels=3,
                   filter_size=8, num_filters=16, pooling=True, name="Conv1")

layer_conv2 = new_conv_layer(input=layer_conv1, num_input_channels=16,
                   filter_size=5, num_filters=7, pooling=True, name="Conv2")

layer_flat, num_features = flatten_layer(layer_conv2, name="Flatten")
layer_fc1 = new_fc_layer(input=layer_flat, num_inputs=num_features, num_outputs=256, relu=True, name="FC1")
layer_fc2 = new_fc_layer(input=layer_fc1, num_inputs=256, num_outputs=16, relu=False, name="FC2")

#LOSS
loss = total_loss(layer_fc2)

#TYPE OF OPTIMIZER
optimizer = tf.train.AdamOptimizer(learning_rate = 1e-4).minimize(loss)

#SIZES
print(x)
print(layer_conv1)
print(layer_conv2)
print(layer_fc1)
print(layer_fc2)
# Out:
# Tensor("x:0", shape=(?, 64, 64, 3), dtype=float32)
# Tensor("MaxPool:0", shape=(?, 28, 28, 16), dtype=float32)
# Tensor("MaxPool_1:0", shape=(?, 12, 12, 7), dtype=float32)
# Tensor("Relu_2:0", shape=(?, 256), dtype=float32)
# Tensor("add_3:0", shape=(?, 16), dtype=float32)

# %%
##Inserting the parameters into the model

batch_size = 32
epochs = 250
iterations_per_epoch = max(len(S_train_img) // batch_size, 1)
num_iterations = epochs * iterations_per_epoch

# %%
batch_size = 32
epochs = 250
iterations_per_epoch = max(len(S_train_img) // batch_size, 1)
num_iterations = epochs * iterations_per_epoch

init = tf.global_variables_initializer()
saver = tf.train.Saver(max_to_keep=None)

logs_path = './logs'
tf.summary.scalar("loss", loss)
merged_summary = tf.summary.merge_all()

with tf.Session() as sess:

    sess.run(init)
    summary_writer = tf.summary.FileWriter(logs_path, sess.graph)
    hist_angles = []
    
    for i in range(0, num_iterations):
        batch_img, batch_class, batch_quat = batch_generator(S_train_img, S_train_class, S_train_quat,
                                                     S_test_img, S_test_class, S_test_quat, batch_size)
        
        _, loss_val, summary = sess.run([optimizer, loss, merged_summary], feed_dict={x: batch_img})

        if i % 10 == 0:
            summary_writer.add_summary(summary, i)
            
        if i % 1000 == 0:
            print("Loss value at iteration " + str(i) + "/" + str(num_iterations-1) + " : " + str(loss_val))
            save_path = saver.save(sess, "./checkpoint/model" + str(i) + ".ckpt")

            db_features, test_features = output_features(S_db_img, S_test_img, layer_fc2, loss, x, i)
            hist, indeces, _ = matching_feature_map(db_features, test_features, S_db_class, S_test_class, S_db_quat, S_test_quat)
            hist_angles.append(hist)
            save_histogram(hist, i)
            print(hist), print()
            
    save_path = saver.save(sess, "./checkpoint/model.ckpt")
    
save_plot_angles(hist_angles)
summary_writer.close()
# Out:
# Loss value at iteration 0/57749 : 8.130266
# INFO:tensorflow:./checkpoint/model0.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model0.ckpt
# [ 0.14144272  1.10325318  4.3281471  28.71287129]
#
# Loss value at iteration 1000/57749 : 1.1443081
# INFO:tensorflow:./checkpoint/model1000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model1000.ckpt
# [ 3.73408769 17.93493635 47.35502122 93.91796322]
#
# Loss value at iteration 2000/57749 : 0.39949083
# INFO:tensorflow:./checkpoint/model2000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model2000.ckpt
# [ 6.13861386 27.86421499 60.70721358 96.03960396]
#
# Loss value at iteration 3000/57749 : 0.27424404
# INFO:tensorflow:./checkpoint/model3000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model3000.ckpt
# [ 9.87270156 38.84016973 74.14427157 98.81188119]
#
# Loss value at iteration 4000/57749 : 0.23851103
# INFO:tensorflow:./checkpoint/model4000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model4000.ckpt
# [ 9.73125884 38.47241867 74.59688826 99.00990099]
#
# Loss value at iteration 5000/57749 : 0.19554734
# INFO:tensorflow:./checkpoint/model5000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model5000.ckpt
# [11.06082037 42.54596888 78.01980198 99.34936351]
#
# Loss value at iteration 6000/57749 : 0.19847235
# INFO:tensorflow:./checkpoint/model6000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model6000.ckpt
# [12.70155587 46.42149929 83.11173975 99.51909477]
#
# Loss value at iteration 7000/57749 : 0.16553336
# INFO:tensorflow:./checkpoint/model7000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model7000.ckpt
# [14.6251768  50.32531825 87.43988685 99.91513437]
#
# Loss value at iteration 8000/57749 : 0.16498412
# INFO:tensorflow:./checkpoint/model8000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model8000.ckpt
# [16.0678925  52.70155587 86.76096181 99.83026874]
#
# Loss value at iteration 9000/57749 : 0.16202113
# INFO:tensorflow:./checkpoint/model9000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model9000.ckpt
# [15.30410184 52.89957567 88.14710042 99.94342291]
#
# Loss value at iteration 10000/57749 : 0.15470827
# INFO:tensorflow:./checkpoint/model10000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model10000.ckpt
# [11.06082037 45.31824611 84.10183876 99.51909477]
#
# Loss value at iteration 11000/57749 : 0.34502944
# INFO:tensorflow:./checkpoint/model11000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model11000.ckpt
# [15.41725601 53.97454031 88.59971711 99.83026874]
#
# Loss value at iteration 12000/57749 : 0.12410284
# INFO:tensorflow:./checkpoint/model12000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model12000.ckpt
# [15.24752475 52.36209335 87.83592645 99.71711457]
#
# Loss value at iteration 13000/57749 : 0.14909619
# INFO:tensorflow:./checkpoint/model13000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model13000.ckpt
# [12.70155587 47.4115983  84.80905233 99.66053748]
#
# Loss value at iteration 14000/57749 : 0.10688153
# INFO:tensorflow:./checkpoint/model14000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model14000.ckpt
# [ 16.74681754  56.94483734  89.22206506 100.        ]
#
# Loss value at iteration 15000/57749 : 0.11992465
# INFO:tensorflow:./checkpoint/model15000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model15000.ckpt
# [16.66195191 55.95473833 89.30693069 99.97171146]
#
# Loss value at iteration 16000/57749 : 0.11460137
# INFO:tensorflow:./checkpoint/model16000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model16000.ckpt
# [16.85997171 57.70862801 90.74964639 99.8019802 ]
#
# Loss value at iteration 17000/57749 : 0.10283168
# INFO:tensorflow:./checkpoint/model17000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model17000.ckpt
# [ 16.66195191  57.42574257  91.96605375 100.        ]
#
# Loss value at iteration 18000/57749 : 0.09512212
# INFO:tensorflow:./checkpoint/model18000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model18000.ckpt
# [16.23762376 57.68033946 92.30551627 99.94342291]
#
# Loss value at iteration 19000/57749 : 0.0883124
# INFO:tensorflow:./checkpoint/model19000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model19000.ckpt
# [17.02970297 59.77369165 92.36209335 99.94342291]
#
# Loss value at iteration 20000/57749 : 0.08767728
# INFO:tensorflow:./checkpoint/model20000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model20000.ckpt
# [15.24752475 54.39886846 90.35360679 99.88684583]
#
# Loss value at iteration 21000/57749 : 0.063710675
# INFO:tensorflow:./checkpoint/model21000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model21000.ckpt
# [18.61386139 58.27439887 91.40028289 99.94342291]
#
# Loss value at iteration 22000/57749 : 0.09147061
# INFO:tensorflow:./checkpoint/model22000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model22000.ckpt
# [17.28429986 57.5106082  91.96605375 99.94342291]
#
# Loss value at iteration 23000/57749 : 0.06564817
# INFO:tensorflow:./checkpoint/model23000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model23000.ckpt
# [18.7553041  60.67892504 93.06930693 99.97171146]
#
# Loss value at iteration 24000/57749 : 0.08724272
# INFO:tensorflow:./checkpoint/model24000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model24000.ckpt
# [17.53889675 56.97312588 91.85289958 99.94342291]
#
# Loss value at iteration 25000/57749 : 0.073024176
# INFO:tensorflow:./checkpoint/model25000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model25000.ckpt
# [16.01131542 56.74681754 91.17397454 99.91513437]
#
# Loss value at iteration 26000/57749 : 0.07317094
# INFO:tensorflow:./checkpoint/model26000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model26000.ckpt
# [18.98161245 61.98019802 93.63507779 99.97171146]
#
# Loss value at iteration 27000/57749 : 0.06616758
# INFO:tensorflow:./checkpoint/model27000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model27000.ckpt
# [14.85148515 54.45544554 90.0990099  99.85855728]
#
# Loss value at iteration 28000/57749 : 0.06613603
# INFO:tensorflow:./checkpoint/model28000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model28000.ckpt
# [17.79349364 59.97171146 93.12588402 99.97171146]
#
# Loss value at iteration 29000/57749 : 0.07581375
# INFO:tensorflow:./checkpoint/model29000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model29000.ckpt
# [15.81329562 56.54879774 91.76803395 99.97171146]
#
# Loss value at iteration 30000/57749 : 0.05963672
# INFO:tensorflow:./checkpoint/model30000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model30000.ckpt
# [19.00990099 60.56577086 93.63507779 99.88684583]
#
# Loss value at iteration 31000/57749 : 0.054163404
# INFO:tensorflow:./checkpoint/model31000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model31000.ckpt
# [17.62376238 60.45261669 93.49363508 99.94342291]
#
# Loss value at iteration 32000/57749 : 0.28577846
# INFO:tensorflow:./checkpoint/model32000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model32000.ckpt
# [19.40594059 60.59405941 93.40876945 99.94342291]
#
# Loss value at iteration 33000/57749 : 0.053292725
# INFO:tensorflow:./checkpoint/model33000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model33000.ckpt
# [19.43422914 60.50919378 93.43705799 99.97171146]
#
# Loss value at iteration 34000/57749 : 0.058332145
# INFO:tensorflow:./checkpoint/model34000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model34000.ckpt
# [18.64214993 61.52758133 93.52192362 99.97171146]
#
# Loss value at iteration 35000/57749 : 0.042943917
# INFO:tensorflow:./checkpoint/model35000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model35000.ckpt
# [20.33946252 64.46958982 95.13437058 99.94342291]
#
# Loss value at iteration 36000/57749 : 0.039598145
# INFO:tensorflow:./checkpoint/model36000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model36000.ckpt
# [20.         63.84724187 94.39886846 99.94342291]
#
# Loss value at iteration 37000/57749 : 0.045738112
# INFO:tensorflow:./checkpoint/model37000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model37000.ckpt
# [21.35785007 63.62093352 93.38048091 99.94342291]
#
# Loss value at iteration 38000/57749 : 0.037493438
# INFO:tensorflow:./checkpoint/model38000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model38000.ckpt
# [18.5572843  60.79207921 93.60678925 99.91513437]
#
# Loss value at iteration 39000/57749 : 0.046317823
# INFO:tensorflow:./checkpoint/model39000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model39000.ckpt
# [20.79207921 62.6874116  94.11598303 99.94342291]
#
# Loss value at iteration 40000/57749 : 0.039422754
# INFO:tensorflow:./checkpoint/model40000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model40000.ckpt
# [21.69731259 64.29985856 94.54031117 99.94342291]
#
# Loss value at iteration 41000/57749 : 0.060229592
# INFO:tensorflow:./checkpoint/model41000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model41000.ckpt
# [15.98302687 55.75671853 92.24893918 99.94342291]
#
# Loss value at iteration 42000/57749 : 0.035938412
# INFO:tensorflow:./checkpoint/model42000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model42000.ckpt
# [20.67892504 63.30975955 94.39886846 99.94342291]
#
# Loss value at iteration 43000/57749 : 0.0314852
# INFO:tensorflow:./checkpoint/model43000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model43000.ckpt
# [19.83026874 60.93352192 93.38048091 99.94342291]
#
# Loss value at iteration 44000/57749 : 0.04255145
# INFO:tensorflow:./checkpoint/model44000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model44000.ckpt
# [21.78217822 64.7241867  94.20084866 99.94342291]
#
# Loss value at iteration 45000/57749 : 0.03338835
# INFO:tensorflow:./checkpoint/model45000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model45000.ckpt
# [22.06506365 63.79066478 93.46534653 99.97171146]
#
# Loss value at iteration 46000/57749 : 0.033182822
# INFO:tensorflow:./checkpoint/model46000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model46000.ckpt
# [20.93352192 63.11173975 93.71994342 99.94342291]
#
# Loss value at iteration 47000/57749 : 0.044539962
# INFO:tensorflow:./checkpoint/model47000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model47000.ckpt
# [20.67892504 62.91371994 94.2291372  99.91513437]
#
# Loss value at iteration 48000/57749 : 0.046822235
# INFO:tensorflow:./checkpoint/model48000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model48000.ckpt
# [ 20.          60.99009901  93.74823197 100.        ]
#
# Loss value at iteration 49000/57749 : 0.14138122
# INFO:tensorflow:./checkpoint/model49000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model49000.ckpt
# [19.06647808 60.79207921 92.02263083 99.97171146]
#
# Loss value at iteration 50000/57749 : 0.02340959
# INFO:tensorflow:./checkpoint/model50000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model50000.ckpt
# [24.55445545 67.55304102 94.76661952 99.97171146]
#
# Loss value at iteration 51000/57749 : 0.03454431
# INFO:tensorflow:./checkpoint/model51000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model51000.ckpt
# [18.18953324 59.34936351 92.72984441 99.97171146]
#
# Loss value at iteration 52000/57749 : 0.046355825
# INFO:tensorflow:./checkpoint/model52000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model52000.ckpt
# [19.51909477 59.6039604  92.41867044 99.97171146]
#
# Loss value at iteration 53000/57749 : 0.04237319
# INFO:tensorflow:./checkpoint/model53000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model53000.ckpt
# [18.7553041  58.64214993 92.56011315 99.97171146]
#
# Loss value at iteration 54000/57749 : 0.020649377
# INFO:tensorflow:./checkpoint/model54000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model54000.ckpt
# [22.65912306 65.09193777 94.71004243 99.97171146]
#
# Loss value at iteration 55000/57749 : 0.037520118
# INFO:tensorflow:./checkpoint/model55000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model55000.ckpt
# [19.66053748 60.3960396  94.17256011 99.97171146]
#
# Loss value at iteration 56000/57749 : 0.026194388
# INFO:tensorflow:./checkpoint/model56000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model56000.ckpt
# [ 22.97029703  64.29985856  93.97454031 100.        ]
#
# Loss value at iteration 57000/57749 : 0.025051683
# INFO:tensorflow:./checkpoint/model57000.ckpt is not in all_model_checkpoint_paths. Manually adding it.
# INFO:tensorflow:Restoring parameters from ./checkpoint/model57000.ckpt
# [ 22.99858557  65.71428571  94.25742574 100.        ]
#
# INFO:tensorflow:./checkpoint/model.ckpt is not in all_model_checkpoint_paths. Manually adding it.

# %%
#index_saved_model = 55000
#db_features, test_features = output_features(S_db_img, S_test_img, layer_fc2, loss, x, index_saved_model)
#hist, indeces, conf_matrix = matching_feature_map(db_features, test_features, S_db_class, S_test_class, S_db_quat, S_test_quat)
#print(hist)

# %%
from tensorflow.contrib.tensorboard.plugins import projector

# %% [markdown]
# ## PCA for feature map (16D → 3D)

# %%
LOG_DIR = './logs'
names = ["ape", "benchvise", "cam", "cat", "duck"]

#Classification of test data in PCA 3D
metadata_file = open(os.path.join(LOG_DIR, 'metadata.tsv'), 'w')
metadata_file.write('Name\tClass\n')
for i in range(len(S_test_class)):
    metadata_file.write('%06d\t%s\n' % (i, names[S_test_class[i]]))
metadata_file.close() 


with tf.Session() as sess:
    
    embedding_var = tf.Variable(test_features,  name='feature_map')
    sess.run(embedding_var.initializer)
    
    summary_writer = tf.summary.FileWriter(LOG_DIR)
    config = projector.ProjectorConfig()
    embedding = config.embeddings.add()
    embedding.tensor_name = embedding_var.name

    #metadata
    embedding.metadata_path = os.path.join('metadata.tsv')

    projector.visualize_embeddings(summary_writer, config)
    saver = tf.train.Saver([embedding_var])
    saver.save(sess, os.path.join(LOG_DIR, 'model2.ckpt'), 1)

# %% [markdown]
# ## Confusion Matrix

# %%
names = ['ape', 'benchvise', 'cam', 'cat', 'duck']
conf_matrix = np.array(conf_matrix, copy = True, dtype = "int16")

df = pd.DataFrame(conf_matrix, index = names, columns = names)

plt.figure(figsize = (10,7))
ax = plt.axes()
sn.heatmap(df, annot=True, annot_kws={"size": 12}, fmt="d")
ax.set_title('Confusion matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

plt.clf()
plt.cla()
plt.close()
